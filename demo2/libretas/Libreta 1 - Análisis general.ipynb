# %% [markdown]
# ## Carga de librerías necesarias para el procesamiento del dataset

# %%
# Se importan las librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Análisis del dataset
#
# ### Lectura del archivo de datos

# %%
# Se hace la lectura del dataset del escenario y se obtiene su cabecera
academicos = pd.read_csv('../datasets/datos_academicos.csv', ',', index_col='Unnamed: 0')
academicos.head()
# Out:
#   unidad_academica carrera nro_inscripcion regular  cnt_readmisiones calidad  \
# 0            FCEQN     170      FCEQN-3342       S               0.0       A
# 1            FCEQN     102      FCEQN-5396       S               0.0       A
# 2            FCEQN     143      FCEQN-3162       S               0.0       A
# 3            FCEQN     106      FCEQN-5739       S               0.0       A
# 4            FCEQN     172            4683       S               0.0       A
#
#   fecha_ingreso_alumno  anio_plan_estudios
# 0           02/28/2011              2005.0
# 1           12/12/2010              2005.0
# 2           03/07/2011              2008.0
# 3           03/12/2011              2008.0
# 4           03/15/2011              2005.0

# %% [markdown]
# ### Registro de meta-datos del dataset
#
# Se van a registrar:
# * Los tipos de datos por atributo
# * El rango de valores que presenta
# * Algunas características de los valores

# %%
# Se define una función general para obtener los meta-datos planteados

def descripcionDatosDataset(datos):
    print("Cantidad de filas:", datos.shape[0])
    print("Cantidad de columnas:", datos.shape[1])
    print('-'*100)
    for columna in datos.columns:
        valoresDescripcion = ''
        tipo = ''
        if datos[columna].dtype == 'float64' or datos[columna].dtype == 'int64':
            tipo = 'numérico'
            valoresDescripcion = datos[columna].agg(['min', 'max', 'mean', 'std', 'median'])
        else:
            tipo = 'nominal' #categórico | string | no-numérico
            valoresDescripcion = {'valoresPresentes' : datos[columna].unique(), 
                                  'cantidadNulos' : datos[columna].isna().sum()}
        print('Columna: ' + columna)
        print('Tipo de datos: ' + tipo)
        print('Descripción de valores:')
        if tipo == 'numérico':
            print(valoresDescripcion)
        else:
            print('-- Valores presentes (10 primeros): ' + str(valoresDescripcion['valoresPresentes'][:10]))
            pctNulos = (valoresDescripcion['cantidadNulos'] / datos.shape[0]) * 100
            print('-- Cantidad de nulos: ' + str(valoresDescripcion['cantidadNulos']) + ' = ' + "{0:.2f}".format(pctNulos) + '%')
        print('-'*100)

# %%
# Se analiza el dataset
descripcionDatosDataset(academicos)
# Out:
# Cantidad de filas: 2316
# Cantidad de columnas: 8
# ----------------------------------------------------------------------------------------------------
# Columna: unidad_academica
# Tipo de datos: nominal
# Descripción de valores:
# -- Valores presentes (10 primeros): ['FCEQN']
# -- Cantidad de nulos: 0 = 0.00%
# ----------------------------------------------------------------------------------------------------
# Columna: carrera
# Tipo de datos: nominal
# Descripción de valores:
# -- Valores presentes (10 primeros): ['170' '102' '143' '106' '172' 'SAC' '114' '147' '101' '104']
# -- Cantidad de nulos: 2 = 0.09%
# ----------------------------------------------------------------------------------------------------
# Columna: nro_inscripcion
# Tipo de datos: nominal
# Descripción de valores:
# -- Valores presentes (10 primeros): ['FCEQN-3342' 'FCEQN-5396' 'FCEQN-3162' 'FCEQN-5739' '4683' 'FCEQN-5233'
#  'FCEQN-5226' 'FCEQN-5117' 'FCEQN-5630' 'FCEQN-5644']
# -- Cantidad de nulos: 0 = 0.00%
# ----------------------------------------------------------------------------------------------------
# Columna: regular
# Tipo de datos: nominal
# Descripción de valores:
# -- Valores presentes (10 primeros): ['S' 'N' nan 'X' 'T' 'SI' 'D']
# -- Cantidad de nulos: 11 = 0.47%
# ----------------------------------------------------------------------------------------------------
# Columna: cnt_readmisiones
# Tipo de datos: numérico
# Descripción de valores:
# min      -2.000000
# max       9.000000
# mean      0.028200
# std       0.307012
# median    0.000000
# Name: cnt_readmisiones, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Columna: calidad
# Tipo de datos: nominal
# Descripción de valores:
# -- Valores presentes (10 primeros): ['A' 'P' 'E' 'N' nan 'X' 'G']
# -- Cantidad de nulos: 10 = 0.43%
# ----------------------------------------------------------------------------------------------------
# Columna: fecha_ingreso_alumno
# Tipo de datos: nominal
# Descripción de valores:
# -- Valores presentes (10 primeros): ['02/28/2011' '12/12/2010' '03/07/2011' '03/12/2011' '03/15/2011'
#  '12/05/2010' '12/14/2010' '12/19/2010' '01/30/2011' '12/04/2010']
# -- Cantidad de nulos: 5 = 0.22%
# ----------------------------------------------------------------------------------------------------
# Columna: anio_plan_estudios
# Tipo de datos: numérico
# Descripción de valores:
# min       1980.000000
# max       2099.000000
# mean      2006.703896
# std          4.487675
# median    2007.000000
# Name: anio_plan_estudios, dtype: float64
# ----------------------------------------------------------------------------------------------------

# %%
# Vista de los valores únicos en los atributos de tipo string

academicos['regular'].unique()

#Vista de la cantidad de ocurrencias de cada valor

pd.value_counts(academicos['regular'])
# Out:
# S     1908
# N      388
# D        4
# X        3
# T        1
# SI       1
# Name: regular, dtype: int64

# %%
# Vista de los valores únicos en los atributos de tipo numérico y obtención de estadísticas


academicos['anio_plan_estudios'].unique()

#Vista de estadísticas del atributo

academicos['anio_plan_estudios'].agg(['min', 'max', 'mean', 'std'])
# Out:
# min     1980.000000
# max     2099.000000
# mean    2006.703896
# std        4.487675
# Name: anio_plan_estudios, dtype: float64

# %% [markdown]
# ### Registro del análisis
#
# 1. Evaluación de valores nulos (filas y columnas)
# 2. Evaluación de formato válido
# 3. Valores ajustados en rangos (ver anexos)
# 4. Claves únicas
# 5. Integridad referencial
# 6. Cumplimiento de reglas en valores

# %%
# Se comienza por obtener la cantidad de filas en las que existen valores nulos
academicos.isnull().sum().sum()
# Out:
# 45

# %%
# Como segundo paso se pasa a obtener la cantidad de nulos por cada columna
academicos.isna().sum()

# Para poder observar el detalle por filas de las columnas con datos nulos
#academicos[academicos['carrera'].isnull()]
# Out:
#     unidad_academica carrera nro_inscripcion regular  cnt_readmisiones  \
# 853            FCEQN     NaN      FCEQN-7254       S               NaN
# 854            FCEQN     NaN      FCEQN-6932       S               NaN
#
#     calidad fecha_ingreso_alumno  anio_plan_estudios
# 853     NaN           04/06/2013              2007.0
# 854     NaN           12/12/2012              2011.0

# %%
# Verificar formato válido - atributo:nro_inscripcion -

# El formato debería ser FCEQN-#### (el número de matrícula del alumno)
# Se puede usar una evaluación de correspondencia con una expresión regular

academicos['nueva'] = academicos['nro_inscripcion'].astype(str).str.match("\D{5}.\d{1,4}$")

# A partir de esto se podría verificar a través de una nueva columna auxiliar
conteo = academicos[academicos.nueva == False]

# Y se cuenta la cantidad de errores de formateo
conteo.shape[0]
# Out:
# 71

# %%
# Verificar que los valores de cada atributo se encuentren dentro de los listados anexos

# Atributo: regular
valores_validos = ['S', 'N'] # Se definen los valores validos según el anexo

# Se identifica y cuenta a los valores que no cumplen esa condición (incluye los nulos)
resultado = academicos[academicos.regular.isin(valores_validos) == False] 

# Vista de las tuplas con valores nulos en el atributo
resultado

# Conteo
#resultado.shape[0]
# Out:
#      unidad_academica carrera nro_inscripcion regular  cnt_readmisiones  \
# 733             FCEQN     106      FCEQN-6979     NaN               0.0
# 734             FCEQN     102      FCEQN-7247     NaN               0.0
# 788             FCEQN     102      FCEQN-6494     NaN               0.0
# 789             FCEQN     106      FCEQN-6735     NaN               0.0
# 962             FCEQN     143      FCEQN-6993     NaN               0.0
# 963             FCEQN     170      FCEQN-7142     NaN               0.0
# 1443            FCEQN     143      FCEQN-7422     NaN               0.0
# 1444            FCEQN     104      FCEQN-7445     NaN               0.0
# 1472            FCEQN     106      FCEQN-5237     NaN               0.0
# 1473            FCEQN     106      FCEQN-6461     NaN               0.0
# 1474            FCEQN     106      FCEQN-6218     NaN               0.0
# 1818            FCEQN     172      FCEQN-8369       X               0.0
# 1859            FCEQN     172      FCEQN-8792       T               0.0
# 1930            FCEQN     147      FCEQN-8685      SI               9.0
# 1985            FCEQN     102      FCEQN-8259       X               0.0
# 2061            FCEQN     104      FCEQN-7128       D               0.0
# 2062            FCEQN     104      FCEQN-7168       D               0.0
# 2063            FCEQN     104      FCEQN-6154       D               0.0
# 2281            FCEQN     104      FCEQN-8698       X               0.0
# 2303            FCEQN     170      FCEQN-8622       D               0.0
#
#      calidad fecha_ingreso_alumno  anio_plan_estudios  nueva
# 733        A           12/15/2012              2012.0   True
# 734        A           03/30/2013              2011.0   True
# 788        A           11/24/2012              2011.0   True
# 789        A           12/04/2012              2012.0   True
# 962        A           12/15/2012              2008.0   True
# 963        A           02/03/2013              2005.0   True
# 1443     NaN           12/01/2013                 NaN   True
# 1444     NaN           12/01/2013              2011.0   True
# 1472       P           04/20/2011              2012.0   True
# 1473       P           04/14/2012              2012.0   True
# 1474       A           04/14/2012              2012.0   True
# 1818       A           12/07/2014              2005.0   True
# 1859       A           02/04/2015              2005.0   True
# 1930       A           12/27/2014              2000.0   True
# 1985       A           12/03/2014              2011.0   True
# 2061       A           02/03/2013              2011.0   True
# 2062       P           02/05/2013              2011.0   True
# 2063       P           02/09/2013              2011.0   True
# 2281       A           02/01/2015              2011.0   True
# 2303       A           06/07/2015              2005.0   True

# %%
#Verificar que los valores de cada atributo se encuentren dentro de los listados anexos

#Atributo: regular
valores = pd.value_counts(academicos['carrera']) #Conteo de ocurrencias por valor (not-null)

academicos[academicos.carrera.isna()] #Para visualizar las tuplas con valores nulos
cantidad_nulos = len(academicos.carrera) - academicos.carrera.count() #Conteo de nulos

valores_validos = ['147',
'172',
'104',
'102',
'101',
'106',
'143',
'SAC',
'170',
'114',
'111',
'105',
'108'] #Se definen los valores validos según el anexo

#Se identifica y cuenta a los valores que no cumplen esa condición (incluye los nulos)
resultado = academicos[academicos.carrera.isin(valores_validos) == False] 
resultado.shape[0]
# Out:
# 8

# %%
#Atributo: cnt_readmisiones
valores = pd.value_counts(academicos['cnt_readmisiones']) #Conteo de ocurrencias por valor (not-null)

academicos[academicos.cnt_readmisiones.isna()] #Para visualizar las tuplas con valores nulos
cantidad_nulos = len(academicos.cnt_readmisiones) - academicos.cnt_readmisiones.count() #Conteo de nulos

#Se identifica y cuenta a los valores que no cumplen las condiciones vistas
resultado = academicos[academicos.cnt_readmisiones < 0] 
menor_cero = resultado.shape[0]

resultado = academicos[academicos.cnt_readmisiones > 5] 
mayor_cero = resultado.shape[0]

cantidad_nulos += menor_cero + mayor_cero
print(cantidad_nulos)
# Out:
# 14

# %%
#Atributo: cnt_readmisiones
valores = pd.value_counts(academicos['anio_plan_estudios']) #Conteo de ocurrencias por valor (not-null)

academicos[academicos.anio_plan_estudios.isna()] #Para visualizar las tuplas con valores nulos
cantidad_nulos = len(academicos.anio_plan_estudios) - academicos.anio_plan_estudios.count() #Conteo de nulos

#Se identifica y cuenta a los valores que no cumplen las condiciones vistas
resultado = academicos[academicos.anio_plan_estudios < 2000] 
res = resultado
menor_cero = resultado.shape[0]

resultado = academicos[academicos.anio_plan_estudios > 2019] 
mayor_cero = resultado.shape[0]

cantidad_nulos += menor_cero + mayor_cero #TODO: adaptar nombres variables
print(cantidad_nulos)

resultado
# Out:
# 9
#      unidad_academica carrera nro_inscripcion regular  cnt_readmisiones  \
# 2244            FCEQN     114      FCEQN-8890       S               0.0
#
#      calidad fecha_ingreso_alumno  anio_plan_estudios  nueva
# 2244       A           05/03/2015              2099.0   True

# %%
#Para revisar problemas de claves duplicadas

#Se obtiene el valor de la cantidad de filas actual
cant_antes = len(academicos) 

#Se ordena el dataset según el atributo que se desee evaluar (requerido para el paso siguiente)
academicos.sort_values("nro_inscripcion", inplace=True)

#Se detectan y eliminan los duplicados en un atributo dejando la última ocurrencia
academicos.drop_duplicates(subset ="nro_inscripcion", keep = 'last', inplace = True)

#Se obtiene el valor posterior a la operación
cant_despues = len(academicos)

#Se imprimen ambos valores
print('Antes del análisis de duplicados: ' + str(cant_antes) + ' - Despues del filtrado de duplicados: ' + str(cant_despues))
# Out:
# Antes del análisis de duplicados: 2316 - Despues del filtrado de duplicados: 2316

# %%
#Para verificar integridad referencial se tienen que importar los otros datasets

#Lectura del dataset de datos_censales
censales = pd.read_csv('../datasets/datos_censales.csv', ',')
censales.head(5)
eliminar = ['Unnamed: 0']
censales.drop(eliminar, inplace=True, axis=1)
censales.head(5)

#Lectura del dataset de datos_persona
persona = pd.read_csv('../datasets/datos_personas.csv', ',')
persona.head(5)
eliminar = ['Unnamed: 0']
persona.drop(eliminar, inplace=True, axis=1)
persona.head(5)
# Out:
#   unidad_academica nro_inscripcion  sexo  nacionalidad  fecha_nac_alumno  \
# 0            FCEQN       FCEQN-877     2           1.0              1987
# 1            FCEQN      FCEQN-1294     2           1.0              1987
# 2            FCEQN      FCEQN-1351     1           1.0              1987
# 3            FCEQN      FCEQN-1363     2           1.0              1987
# 4            FCEQN      FCEQN-1367     2           1.0              1987
#
#    fecha_egr_sec
# 0           2004
# 1           2011
# 2           2011
# 3           2011
# 4           2011

# %%
#Antes de probar la integración se debe verificar la unicidad de las claves en los otros datasets 
#Se obtiene el valor de la cantidad de filas actual
cant_antes = len(censales) 

#Se ordena el dataset según el atributo que se desee evaluar (requerido para el paso siguiente)
censales.sort_values("insc", inplace=True)

#Se detectan y eliminan los duplicados en un atributo dejando la última ocurrencia
censales.drop_duplicates(subset ="insc", keep = 'last', inplace = True)

#Se obtiene el valor posterior a la operación
cant_despues = len(censales)

#Se imprimen ambos valores
print('Antes: ' + str(cant_antes) + ' - Despues: ' + str(cant_despues))
# Out:
# Antes: 3875 - Despues: 3875

# %%
#Antes de probar la integración se debe verificar la unicidad de las claves en los otros datasets 
#Se obtiene el valor de la cantidad de filas actual
cant_antes = len(persona) 

#Se ordena el dataset según el atributo que se desee evaluar (requerido para el paso siguiente)
persona.sort_values("nro_inscripcion", inplace=True)

#Se detectan y eliminan los duplicados en un atributo dejando la última ocurrencia
persona.drop_duplicates(subset ="nro_inscripcion", keep = 'last', inplace = True)

#Se obtiene el valor posterior a la operación
cant_despues = len(persona)

#Se imprimen ambos valores
print('Antes: ' + str(cant_antes) + ' - Despues: ' + str(cant_despues))
# Out:
# Antes: 3875 - Despues: 3875

# %%
#Las uniones se hacen de a pares - revisar nombres de atributos
semi_completo = pd.merge(persona, academicos, on='nro_inscripcion', how='inner')
semi_completo.shape[0]

#Para verificar se puede ejecutar
#semi_completo
# Out:
# 2316

# %%
cambios = {'insc' : 'nro_inscripcion'}
censales.rename(columns=cambios, inplace=True)
censales.head(1)
# Out:
#        ua nro_inscripcion  estado_civil sit_lab_alumno  tipo_res_nuevo  \
# 41  FCEQN            1024           1.0             NC            -1.0
#
#     sit_lab_padres  estudios_padres
# 41              -1             -1.0

# %%
#Las uniones se hacen de a pares - revisar nombres de atributos
completo = pd.merge(censales, semi_completo, on='nro_inscripcion', how='inner')
completo.shape[0]

#Para verificar se puede ejecutar
completo.head(2)
# Out:
#       ua nro_inscripcion  estado_civil sit_lab_alumno  tipo_res_nuevo  \
# 0  FCEQN            1024           1.0             NC            -1.0
# 1  FCEQN            1041           1.0             NC            -1.0
#
#    sit_lab_padres  estudios_padres unidad_academica_x  sexo  nacionalidad  \
# 0              -1             -1.0              FCEQN     2           1.0
# 1              -1             -1.0              FCEQN     2           1.0
#
#    fecha_nac_alumno  fecha_egr_sec unidad_academica_y carrera regular  \
# 0              1981           2011              FCEQN     114       S
# 1              1979           2011              FCEQN     170       N
#
#    cnt_readmisiones calidad fecha_ingreso_alumno  anio_plan_estudios  nueva
# 0               0.0       A           05/10/2011              2005.0  False
# 1               0.0       A           03/30/2013              2005.0  False

# %%
#Finalmente (última verificación) se revisan cuestiones de aplicación de reglas en los valores del nuevo dataset

#Regla: año egreso secundario no puede ser mayor a año de ingreso a la carrera

#Muestra
fecha_i = completo.fecha_ingreso_alumno.iloc[0]
#fecha_i
ingreso = int(fecha_i[-4:])
#ingreso
egreso = int(completo.fecha_egr_sec.iloc[0])
diferencia = ingreso - egreso
#egreso

print('Ingreso carrera: ' + str(ingreso) + 
      ' Egreso nivel medio: ' + str(egreso) + 
      ' Diferencia: ' + str(diferencia))
# Out:
# Ingreso carrera: 2011 Egreso nivel medio: 2011 Diferencia: 0

# %%
#Se puede definir una función para aplicar los cálculos
def reglaAnioSecundario(row):
    #fecha_ingreso_alumno es tipo date
    anio_ingreso = int(row['fecha_ingreso_alumno'][-4:]) #Se aisla el año
    
    anio_egreso_secundaria = int(row['fecha_egr_sec'])
    diferencia = anio_ingreso - anio_egreso_secundaria
    if (diferencia < 0):
        #Es un error ya que no podría entrar al nivel superior sin haber finalizado en el nivel medio
        return 'err'
    else:
        return 'ok'


pd.value_counts(completo.fecha_ingreso_alumno)
completo['fecha_ingreso_alumno'].fillna('12/12/2010',inplace=True)
    

#Se aplica la función para todos los elementos del dataset
completo['diferencia_nivel'] = completo.apply(lambda row: reglaAnioSecundario(row), axis=1)

#Se verifica la cantidad de elementos
aux = completo[completo.diferencia_nivel == 'err']
#len(aux)
aux
# Out:
#          ua nro_inscripcion  estado_civil sit_lab_alumno  tipo_res_nuevo  \
# 2     FCEQN            1057           1.0             NC             4.0
# 4     FCEQN            1382           1.0             NC             1.0
# 5     FCEQN            1439           1.0             NC            -1.0
# 7     FCEQN            1488           1.0             NC            -1.0
# 11    FCEQN            1576           1.0             NC            -1.0
# 12    FCEQN            1666           1.0             NC            -1.0
# 15    FCEQN            1711           1.0             NC            -1.0
# 17    FCEQN            1764           1.0             NC            -1.0
# 18    FCEQN            1767           1.0             NC             4.0
# 19    FCEQN            1772           1.0             NC            -1.0
# 25    FCEQN            3219           1.0             NC            -1.0
# 26    FCEQN            3260           1.0             NC             1.0
# 27    FCEQN            3365           2.0             Si             4.0
# 28    FCEQN            3428           1.0              1             3.0
# 29    FCEQN             350           2.0              1             1.0
# 36    FCEQN            4470           1.0             NC             1.0
# 42    FCEQN            4865           2.0             NC             4.0
# 48    FCEQN            5103           3.0             NC             4.0
# 50    FCEQN            5130           1.0             No             1.0
# 52    FCEQN            5204           2.0             No             4.0
# 55    FCEQN            5689           3.0             NC            -1.0
# 58    FCEQN            5863           1.0             NC            -1.0
# 66    FCEQN             775           2.0             NC            -1.0
# 67    FCEQN             840           1.0             No             1.0
# 68    FCEQN             944           2.0             NC             4.0
# 73    FCEQN      FCEQN-1116           1.0             NC            -1.0
# 74    FCEQN      FCEQN-1165           1.0             NC            -1.0
# 77    FCEQN      FCEQN-1181           1.0             NC             2.0
# 78    FCEQN      FCEQN-1213           1.0             NC             1.0
# 80    FCEQN      FCEQN-1283           1.0             NC             3.0
# ...     ...             ...           ...            ...             ...
# 609   FCEQN      FCEQN-5603           1.0             NC             1.0
# 612   FCEQN      FCEQN-5608           1.0             NC             4.0
# 613   FCEQN      FCEQN-5609           1.0             NC             1.0
# 614   FCEQN      FCEQN-5612           1.0             NC             1.0
# 615   FCEQN      FCEQN-5614           1.0             NC             1.0
# 616   FCEQN      FCEQN-5615           1.0             NC            -1.0
# 618   FCEQN      FCEQN-5618           1.0             NC            -1.0
# 619   FCEQN      FCEQN-5619           1.0             NC            -1.0
# 620   FCEQN      FCEQN-5620           1.0             NC             2.0
# 621   FCEQN      FCEQN-5621           1.0             NC            -1.0
# 622   FCEQN      FCEQN-5622           1.0             NC            -1.0
# 623   FCEQN      FCEQN-5623           1.0             NC            -1.0
# 625   FCEQN      FCEQN-5625           1.0             NC            -1.0
# 627   FCEQN      FCEQN-5627           1.0             NC             4.0
# 630   FCEQN      FCEQN-5631           1.0             NC             4.0
# 678   FCEQN      FCEQN-5715           1.0             NC            -1.0
# 758   FCEQN      FCEQN-5832           1.0             NC            -1.0
# 843   FCEQN      FCEQN-5983           1.0             NC            -1.0
# 1380  FCEQN      FCEQN-6972           1.0             NC            -1.0
# 1392  FCEQN      FCEQN-6992           1.0             NC            -1.0
# 1483  FCEQN       FCEQN-720           1.0             NC             4.0
# 1521  FCEQN      FCEQN-7263           1.0             NC             1.0
# 1532  FCEQN       FCEQN-731           1.0             NC             4.0
# 1559  FCEQN      FCEQN-7369           1.0             NC            -1.0
# 1674  FCEQN       FCEQN-758           1.0             NC             3.0
# 2161  FCEQN      FCEQN-8594           1.0             NC             1.0
# 2253  FCEQN      FCEQN-8789           1.0             NC            -1.0
# 2288  FCEQN       FCEQN-888           1.0             NC             1.0
# 2299  FCEQN      FCEQN-8892           2.0             NC             1.0
# 2300  FCEQN      FCEQN-8894           4.0             NC             1.0
#
#       sit_lab_padres  estudios_padres unidad_academica_x  sexo  nacionalidad  \
# 2                  1              4.0              FCEQN     2           1.0
# 4                 -1             -1.0              FCEQN     2           1.0
# 5                 -1             -1.0              FCEQN     2           1.0
# 7                 -1             -1.0              FCEQN     2           1.0
# 11                -1             -1.0              FCEQN     1           1.0
# 12                -1             -1.0              FCEQN     2           1.0
# 15                -1             -1.0              FCEQN     1           1.0
# 17                -1             -1.0              FCEQN     1           1.0
# 18                -1             -1.0              FCEQN     2           1.0
# 19                -1             -1.0              FCEQN     2           1.0
# 25                -1             -1.0              FCEQN     2           1.0
# 26                -1             -1.0              FCEQN     2           1.0
# 27                 2              3.0              FCEQN     2           2.0
# 28                 1              5.0              FCEQN     2           1.0
# 29                 4              5.0              FCEQN     2           1.0
# 36                 4              5.0              FCEQN     1           1.0
# 42                 3              5.0              FCEQN     1           1.0
# 48                -1             -1.0              FCEQN     1           1.0
# 50                 1              3.0              FCEQN     2           1.0
# 52                 4              5.0              FCEQN     1           1.0
# 55                -1             -1.0              FCEQN     2           1.0
# 58                -1             -1.0              FCEQN     2           1.0
# 66                -1             -1.0              FCEQN     1           1.0
# 67                 4              4.0              FCEQN     2           1.0
# 68                 4              5.0              FCEQN     1           1.0
# 73                -1             -1.0              FCEQN     1           1.0
# 74                -1             -1.0              FCEQN     1           1.0
# 77                -1             -1.0              FCEQN     1           1.0
# 78                -1             -1.0              FCEQN     1           1.0
# 80                 1              5.0              FCEQN     2           1.0
# ...              ...              ...                ...   ...           ...
# 609                1              7.0              FCEQN     1           1.0
# 612                3              5.0              FCEQN     2           1.0
# 613                3              5.0              FCEQN     2           1.0
# 614                1              5.0              FCEQN     2           1.0
# 615                1              4.0              FCEQN     2           1.0
# 616                1              5.0              FCEQN     1           1.0
# 618                3              5.0              FCEQN     1           1.0
# 619               -1             -1.0              FCEQN     2           1.0
# 620                3              5.0              FCEQN     2           1.0
# 621               -1             -1.0              FCEQN     1           1.0
# 622                1              5.0              FCEQN     1           1.0
# 623                1              5.0              FCEQN     2           1.0
# 625               -1             -1.0              FCEQN     2           1.0
# 627                4              3.0              FCEQN     2           1.0
# 630                1              5.0              FCEQN     2           2.0
# 678               -1             -1.0              FCEQN     1           1.0
# 758                3              3.0              FCEQN     2           1.0
# 843                3              4.0              FCEQN     2           1.0
# 1380               4              5.0              FCEQN     1           1.0
# 1392              -1             -1.0              FCEQN     1           1.0
# 1483               4              5.0              FCEQN     1           1.0
# 1521              -1             -1.0              FCEQN     2           1.0
# 1532               4              3.0              FCEQN     1           1.0
# 1559              -1              1.0              FCEQN     2           1.0
# 1674              -1              7.0              FCEQN     2           1.0
# 2161               2              2.0              FCEQN     2           1.0
# 2253              -1              7.0              FCEQN     2           1.0
# 2288               4              3.0              FCEQN     1           1.0
# 2299              -1             -1.0              FCEQN     1           1.0
# 2300              -1             -1.0              FCEQN     2           1.0
#
#             ...         fecha_egr_sec  unidad_academica_y carrera regular  \
# 2           ...                  2011               FCEQN     104       S
# 4           ...                  2011               FCEQN     102       S
# 5           ...                  2011               FCEQN     104       N
# 7           ...                  2011               FCEQN     105       S
# 11          ...                  2011               FCEQN     102       S
# 12          ...                  2011               FCEQN     102       S
# 15          ...                  2011               FCEQN     102       S
# 17          ...                  2011               FCEQN     102       S
# 18          ...                  2011               FCEQN     102       S
# 19          ...                  2011               FCEQN     102       S
# 25          ...                  2011               FCEQN     104       N
# 26          ...                  2011               FCEQN     104       S
# 27          ...                  2011               FCEQN     102       S
# 28          ...                  2011               FCEQN     104       S
# 29          ...                  2011               FCEQN     108       N
# 36          ...                  2011               FCEQN     147       S
# 42          ...                  2011               FCEQN     101       S
# 48          ...                  2011               FCEQN     101       N
# 50          ...                  2011               FCEQN     106       S
# 52          ...                  2011               FCEQN     170       S
# 55          ...                  2011               FCEQN     103       N
# 58          ...                  2011               FCEQN     147       N
# 66          ...                  2011               FCEQN     102       N
# 67          ...                  2011               FCEQN     103       S
# 68          ...                  2011               FCEQN     102       N
# 73          ...                  2011               FCEQN     104       S
# 74          ...                  2011               FCEQN     101       S
# 77          ...                  2011               FCEQN     172       N
# 78          ...                  2011               FCEQN     172       S
# 80          ...                  2011               FCEQN     102       S
# ...         ...                   ...                 ...     ...     ...
# 609         ...                  2011               FCEQN     147       N
# 612         ...                  2011               FCEQN     SAC       S
# 613         ...                  2011               FCEQN     147       N
# 614         ...                  2011               FCEQN     147       S
# 615         ...                  2011               FCEQN     172       N
# 616         ...                  2011               FCEQN     SAC       N
# 618         ...                  2011               FCEQN     147       S
# 619         ...                  2011               FCEQN     147       S
# 620         ...                  2011               FCEQN     SAC       N
# 621         ...                  2011               FCEQN     SAC       S
# 622         ...                  2011               FCEQN     147       S
# 623         ...                  2011               FCEQN     104       S
# 625         ...                  2011               FCEQN     102       S
# 627         ...                  2011               FCEQN     147       S
# 630         ...                  2011               FCEQN     147       S
# 678         ...                  2012               FCEQN     SAC       N
# 758         ...                  2012               FCEQN     101       N
# 843         ...                  2012               FCEQN     101       N
# 1380        ...                  2011               FCEQN     104       S
# 1392        ...                  2011               FCEQN     143       S
# 1483        ...                  2011               FCEQN     101       N
# 1521        ...                  2011               FCEQN     143       S
# 1532        ...                  2011               FCEQN     102       S
# 1559        ...                  2014               FCEQN     104       S
# 1674        ...                  2011               FCEQN     102       S
# 2161        ...                  2011               FCEQN     102       S
# 2253        ...                  2014               FCEQN     147       S
# 2288        ...                  2011               FCEQN     102       S
# 2299        ...                  2011               FCEQN     111       S
# 2300        ...                  2011               FCEQN     111       S
#
#      cnt_readmisiones  calidad fecha_ingreso_alumno anio_plan_estudios  nueva  \
# 2                 1.0        A           02/19/2003             2011.0  False
# 4                 2.0        A           02/10/1998             2005.0  False
# 5                 1.0        P           04/26/2004             2011.0  False
# 7                 0.0        P           10/08/2008             2008.0  False
# 11                2.0        A           07/28/2001             2011.0  False
# 12                0.0        A           02/14/1998             2005.0  False
# 15                0.0        P           02/19/2003             2011.0  False
# 17                0.0        A           02/19/2003             2005.0  False
# 18                0.0        A           02/19/2003             2005.0  False
# 19                1.0        A           02/19/2003             2005.0  False
# 25                0.0        P           12/23/1997             2009.0  False
# 26                0.0        A           03/01/2000             2005.0  False
# 27                0.0        E           02/20/2003             2000.0  False
# 28                0.0        A           12/16/1996             2005.0  False
# 29                0.0        P           04/25/2010             2010.0  False
# 36                2.0        A           03/01/2000             2000.0  False
# 42                2.0        A           02/08/1995             2004.0  False
# 48                0.0        P           03/09/1999             2006.0  False
# 50                1.0        A           04/05/2010             2008.0  False
# 52                0.0        A           12/14/2010             2005.0  False
# 55                2.0        P           03/01/1991             2005.0  False
# 58                2.0        A           03/01/2000             2000.0  False
# 66                1.0        A           05/19/1996             2005.0  False
# 67                0.0        E           03/15/2009             2005.0  False
# 68                1.0        A           04/02/1994             2005.0  False
# 73                0.0        A           05/09/2005             2011.0   True
# 74                0.0        A           05/11/2005             2007.0   True
# 77                2.0        P           05/11/2005             2005.0   True
# 78                0.0        E           05/11/2005             2005.0   True
# 80                0.0        A           05/14/2005             2011.0   True
# ...               ...      ...                  ...                ...    ...
# 609               0.0        P           12/15/2010             2000.0   True
# 612               0.0        A           12/15/2010             2009.0   True
# 613               0.0        P           12/15/2010             2000.0   True
# 614               0.0        A           12/15/2010             2000.0   True
# 615               0.0        P           12/15/2010             2005.0   True
# 616               0.0        P           12/27/2010             2009.0   True
# 618               0.0        A           12/18/2010             2000.0   True
# 619               0.0        A           12/18/2010             2000.0   True
# 620               0.0        P           12/18/2010             2009.0   True
# 621               0.0        A           12/18/2010             2009.0   True
# 622               0.0        A           12/18/2010             2000.0   True
# 623               0.0        A           12/19/2010             2005.0   True
# 625               0.0        A           12/19/2010             2005.0   True
# 627               0.0        A           12/19/2010             2000.0   True
# 630               0.0        A           12/20/2010             2000.0   True
# 678               0.0        P           02/02/2011             2009.0   True
# 758               0.0        P           11/28/2011             2007.0   True
# 843               0.0        A           12/07/2011             2007.0   True
# 1380              0.0        A           12/12/2010             2011.0   True
# 1392              0.0        A           12/12/2010             2008.0   True
# 1483              0.0        A           02/05/2006             2007.0   True
# 1521              0.0        A           12/12/2010             2008.0   True
# 1532              0.0        A           05/02/2004             2005.0   True
# 1559              0.0        A           06/08/1980             2011.0   True
# 1674              1.0        A           05/03/2004             2005.0   True
# 2161              0.0        A           12/16/1991             2011.0   True
# 2253              0.0      NaN           02/04/1950             2000.0   True
# 2288              0.0        A           05/02/2005             2005.0   True
# 2299              0.0        A           12/12/2010             2014.0   True
# 2300              0.0        A           12/12/2010             2014.0   True
#
#       diferencia_nivel
# 2                  err
# 4                  err
# 5                  err
# 7                  err
# 11                 err
# 12                 err
# 15                 err
# 17                 err
# 18                 err
# 19                 err
# 25                 err
# 26                 err
# 27                 err
# 28                 err
# 29                 err
# 36                 err
# 42                 err
# 48                 err
# 50                 err
# 52                 err
# 55                 err
# 58                 err
# 66                 err
# 67                 err
# 68                 err
# 73                 err
# 74                 err
# 77                 err
# 78                 err
# 80                 err
# ...                ...
# 609                err
# 612                err
# 613                err
# 614                err
# 615                err
# 616                err
# 618                err
# 619                err
# 620                err
# 621                err
# 622                err
# 623                err
# 625                err
# 627                err
# 630                err
# 678                err
# 758                err
# 843                err
# 1380               err
# 1392               err
# 1483               err
# 1521               err
# 1532               err
# 1559               err
# 1674               err
# 2161               err
# 2253               err
# 2288               err
# 2299               err
# 2300               err
#
# [318 rows x 21 columns]

# %%
new = completo[completo['estado_civil'] > 1]
new.head()
# Out:
#        ua nro_inscripcion  estado_civil sit_lab_alumno  tipo_res_nuevo  \
# 9   FCEQN            1554           2.0             NC             1.0
# 16  FCEQN            1736           2.0             No             1.0
# 22  FCEQN            2010           2.0             NC             1.0
# 23  FCEQN            2920           2.0             NC            -1.0
# 24  FCEQN             309           2.0             NC             1.0
#
#     sit_lab_padres  estudios_padres unidad_academica_x  sexo  nacionalidad  \
# 9                4              4.0              FCEQN     2           1.0
# 16               1              6.0              FCEQN     2           1.0
# 22              -1             -1.0              FCEQN     2           1.0
# 23              -1             -1.0              FCEQN     2           1.0
# 24               1              3.0              FCEQN     2           1.0
#
#           ...         fecha_egr_sec  unidad_academica_y carrera regular  \
# 9         ...                  2011               FCEQN     104       S
# 16        ...                  2011               FCEQN     104       S
# 22        ...                  2011               FCEQN     105       S
# 23        ...                  2011               FCEQN     114       S
# 24        ...                  2011               FCEQN     104       S
#
#    cnt_readmisiones  calidad fecha_ingreso_alumno anio_plan_estudios  nueva  \
# 9               0.0        A           02/28/2015             2011.0  False
# 16              0.0        A           02/04/2015             2011.0  False
# 22              0.0        A           04/04/2015             2008.0  False
# 23              0.0        A           05/10/2011             2005.0  False
# 24              0.0        A           03/02/2011             2005.0  False
#
#     diferencia_nivel
# 9                 ok
# 16                ok
# 22                ok
# 23                ok
# 24                ok
#
# [5 rows x 21 columns]
